# %%
import pandas as pd
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df=pd.DataFrame([[101,25,35000],[105,20,28000],[107,19,21000]])
df
# Out:
#      0   1      2
# 0  101  25  35000
# 1  105  20  28000
# 2  107  19  21000

# %%
df=pd.DataFrame([[101,25,35000],[105,20,28000],[107,19,21000]],columns=['id','age','sal'])
df
# Out:
#     id  age    sal
# 0  101   25  35000
# 1  105   20  28000
# 2  107   19  21000

# %%
print(df)
# Out:
#     id  age    sal
# 0  101   25  35000
# 1  105   20  28000
# 2  107   19  21000

# %%
df=pd.DataFrame({'id':[101,102,103],'Age':[20,19,25],'sal':[35000,28000,32000]})
df
# Out:
#     id  Age    sal
# 0  101   20  35000
# 1  102   19  28000
# 2  103   25  32000

# %%
i=[1,2,3]
a=(20,18,25)
import numpy as np
s=np.random.randint(10000,20000,3)
df=pd.DataFrame({'Id':i,'Age':a,'Sal':s})
df
# Out:
#    Id  Age    Sal
# 0   1   20  15774
# 1   2   18  11860
# 2   3   25  16428

# %%
df.shape
# Out:
# (3, 3)

# %%
df.dtypes
# Out:
# Id     int64
# Age    int64
# Sal    int32
# dtype: object

# %%
df.size
# Out:
# 9

# %%
df.columns
# Out:
# Index(['Id', 'Age', 'Sal'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns=['empid','age','empsal']

# %%
df
# Out:
#    empid  age  empsal
# 0      1   20   15774
# 1      2   18   11860
# 2      3   25   16428

# %%
df.index=['r1','r2','r3']

# %%
df
# Out:
#     empid  age  empsal
# r1      1   20   15774
# r2      2   18   11860
# r3      3   25   16428

# %%
df=pd.read_excel("d:/test.xlsx",sheet_name='Sheet1')
df
# Out:
#    101    20     35000
# 0    102     25  40000
# 1    103     19  25000

# %%
df=pd.read_excel("d:/test.xlsx",sheet_name='Sheet2')
df
# Out:
#     ID  Age    Sal
# 0  101   20  35000
# 1  102   25  40000
# 2  103   19  25000

# %%
df=pd.read_excel("d:/test.xlsx",sheet_name='Sheet1',header=None)
df
# Out:
#      0   1      2
# 0  101  20  35000
# 1  102  25  40000
# 2  103  19  25000

# %%
df=pd.read_excel("d:/test.xlsx",sheet_name='Sheet1',header=None,names=['Id','Age','sal'])
df
# Out:
#     Id  Age    sal
# 0  101   20  35000
# 1  102   25  40000
# 2  103   19  25000

# %%
df=pd.read_excel("d:/test.xlsx",sheet_name='Sheet3')
df
# Out:
#        ID   Age  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6  \
# 0   101.0  20.0     35000.0         NaN         NaN         NaN        NaN
# 1   102.0   NaN     40000.0         NaN         NaN         NaN        NaN
# 2     NaN  19.0     25000.0         NaN         NaN         NaN        Sal
# 3     NaN   NaN         NaN         NaN         NaN         NaN        NaN
# 4     NaN   NaN         NaN         NaN         NaN         NaN        NaN
# 5     NaN   NaN         NaN         NaN         NaN         NaN        NaN
# 6     NaN   NaN         NaN         NaN         NaN         NaN        NaN
# 7     NaN   NaN         NaN         NaN         NaN         NaN        NaN
# 8     NaN   NaN         NaN         NaN         NaN         NaN        NaN
# 9     NaN   NaN         NaN         NaN         NaN         NaN        NaN
# 10    NaN   NaN         NaN         NaN         NaN         NaN        NaN
# ...

# %%
df=pd.read_excel("c:/Users/Raju/Downloads/movies_sheets.xls",sheet_name='1900s')
df
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                           Category Language  Country Content Rating  Duration  \
# 0                Drama|History|War      NaN      USA      Not Rated       123
# ...

# %%
df=pd.read_excel("c:/Users/Raju/Downloads/movies_sheets.xls",sheet_name='2000s')
df.shape
# Out:
# (2100, 25)

# %%
df
# Out:
#                                   Title  Year  \
# 0                       102 Dalmatians   2000
# 1                              28 Days   2000
# 2                            3 Strikes   2000
# 3                             Aberdeen   2000
# 4                All the Pretty Horses   2000
# ...                                 ...   ...
# 2095          X-Men Origins: Wolverine   2009
# 2096                          Year One   2009
# 2097                   Youth in Revolt   2009
# 2098  ZMD: Zombies of Mass Destruction   2009
# 2099                        Zombieland   2009
#
#                                       Category Language Country  \
# 0                      Adventure|Comedy|Family  English     USA
# 1                                 Comedy|Drama  English     USA
# 2                                       Comedy  English     USA
# 3                                        Drama  English      UK
# 4                        Drama|Romance|Western  English     USA
# ...

# %%
df=pd.read_excel("c:/Users/Raju/Downloads/movies_sheets.xls",sheet_name=0)
df
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                           Category Language  Country Content Rating  Duration  \
# 0                Drama|History|War      NaN      USA      Not Rated       123
# ...

# %%
df_dict=pd.read_excel("c:/Users/Raju/Downloads/movies_sheets.xls",sheet_name=None)
df_dict
# Out:
# {'1900s':                                                   Title  Year  \
#  0     Intolerance: Love's Struggle Throughout the Ages   1916
#  1                       Over the Hill to the Poorhouse   1920
#  2                                       The Big Parade   1925
#  3                                           Metropolis   1927
#  4                                        Pandora's Box   1929
#  ...                                                 ...   ...
#  1333                                  Twin Falls Idaho   1999
#  1334                     Universal Soldier: The Return   1999
#  1335                                     Varsity Blues   1999
#  1336                                    Wild Wild West   1999
#  1337                                    Wing Commander   1999
#
#                            Category Language  Country Content Rating  Duration  \
#  0                Drama|History|War      NaN      USA      Not Rated       123
# ...

# %%
df_dict.keys()
# Out:
# dict_keys(['1900s', '2000s', '2010s'])

# %%
df_dict['1900s'].shape
# Out:
# (1338, 25)

# %%
df1=df_dict['1900s']
df1.shape
# Out:
# (1338, 25)

# %%
df1
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                           Category Language  Country Content Rating  Duration  \
# 0                Drama|History|War      NaN      USA      Not Rated       123
# ...

# %%
df2=df_dict['2000s']
df2.shape
# Out:
# (2100, 25)

# %%
df3=df_dict['2010s']
df3.shape
# Out:
# (1604, 25)

# %%
df2
# Out:
#                                   Title  Year  \
# 0                       102 Dalmatians   2000
# 1                              28 Days   2000
# 2                            3 Strikes   2000
# 3                             Aberdeen   2000
# 4                All the Pretty Horses   2000
# ...                                 ...   ...
# 2095          X-Men Origins: Wolverine   2009
# 2096                          Year One   2009
# 2097                   Youth in Revolt   2009
# 2098  ZMD: Zombies of Mass Destruction   2009
# 2099                        Zombieland   2009
#
#                                       Category Language Country  \
# 0                      Adventure|Comedy|Family  English     USA
# 1                                 Comedy|Drama  English     USA
# 2                                       Comedy  English     USA
# 3                                        Drama  English      UK
# 4                        Drama|Romance|Western  English     USA
# ...

# %%
df3
# Out:
#                                      Title    Year  \
# 0                               127 Hours   2010.0
# 1                             3 Backyards   2010.0
# 2                                       3   2010.0
# 3               8: The Mormon Proposition   2010.0
# 4     A Turtle's Tale: Sammy's Adventures   2010.0
# ...                                    ...     ...
# 1599              War & Peace                  NaN
# 1600                    Wings                  NaN
# 1601               Wolf Creek                  NaN
# 1602        Wuthering Heights                  NaN
# 1603  Yu-Gi-Oh! Duel Monsters                  NaN
#
#                                        Category  Language    Country  \
# 0            Adventure|Biography|Drama|Thriller   English        USA
# 1                                         Drama   English        USA
# 2                          Comedy|Drama|Romance    German    Germany
# 3                                   Documentary   English        USA
# ...

# %%
df=pd.read_excel("c:/Users/Raju/Downloads/movies_sheets.xls")
df
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                           Category Language  Country Content Rating  Duration  \
# 0                Drama|History|War      NaN      USA      Not Rated       123
# ...

# %%
df=pd.read_excel("c:/Users/Raju/Downloads/movies_sheets.xls",nrows=50)
df
# Out:
#                                                 Title  Year  \
# 0   Intolerance: Love's Struggle Throughout the Ages   1916
# 1                     Over the Hill to the Poorhouse   1920
# 2                                     The Big Parade   1925
# 3                                         Metropolis   1927
# 4                                      Pandora's Box   1929
# 5                                The Broadway Melody   1929
# 6                                      Hell's Angels   1930
# 7                                 A Farewell to Arms   1932
# 8                                        42nd Street   1933
# 9                                 She Done Him Wrong   1933
# 10                             It Happened One Night   1934
# 11                                           Top Hat   1935
# 12                                      Modern Times   1936
# 13                   The Charge of the Light Brigade   1936
# 14                   Snow White and the Seven Dwarfs   1937
# ...

# %%
df=pd.read_excel("c:/Users/Raju/Downloads/movies_sheets.xls",nrows=50,skiprows=range(1,4))
df
# Out:
#                                Title  Year  \
# 0                        Metropolis   1927
# 1                     Pandora's Box   1929
# 2               The Broadway Melody   1929
# 3                     Hell's Angels   1930
# 4                A Farewell to Arms   1932
# 5                       42nd Street   1933
# 6                She Done Him Wrong   1933
# 7             It Happened One Night   1934
# 8                           Top Hat   1935
# 9                      Modern Times   1936
# 10  The Charge of the Light Brigade   1936
# 11  Snow White and the Seven Dwarfs   1937
# 12            The Prisoner of Zenda   1937
# 13         Alexander's Ragtime Band   1938
# 14       You Can't Take It with You   1938
# 15               Gone with the Wind   1939
# 16     Mr. Smith Goes to Washington   1939
# 17                 The Wizard of Oz   1939
# 18                        Boom Town   1940
# 19                         Fantasia   1940
# 20                        Pinocchio   1940
# ...

# %%
df=pd.read_excel("c:/Users/Raju/Downloads/movies_sheets.xls",nrows=50,skiprows=range(1,10,2))
df
# Out:
#                                Title  Year  \
# 0    Over the Hill to the Poorhouse   1920
# 1                        Metropolis   1927
# 2               The Broadway Melody   1929
# 3                A Farewell to Arms   1932
# 4                She Done Him Wrong   1933
# 5             It Happened One Night   1934
# 6                           Top Hat   1935
# 7                      Modern Times   1936
# 8   The Charge of the Light Brigade   1936
# 9   Snow White and the Seven Dwarfs   1937
# 10            The Prisoner of Zenda   1937
# 11         Alexander's Ragtime Band   1938
# 12       You Can't Take It with You   1938
# 13               Gone with the Wind   1939
# 14     Mr. Smith Goes to Washington   1939
# 15                 The Wizard of Oz   1939
# 16                        Boom Town   1940
# 17                         Fantasia   1940
# 18                        Pinocchio   1940
# 19                          Rebecca   1940
# 20                    The Blue Bird   1940
# ...

# %%
df=pd.read_excel("c:/Users/Raju/Downloads/movies_sheets.xls",nrows=50,skiprows=[1,5,7,9])
df
# Out:
#                                Title  Year  \
# 0    Over the Hill to the Poorhouse   1920
# 1                    The Big Parade   1925
# 2                        Metropolis   1927
# 3               The Broadway Melody   1929
# 4                A Farewell to Arms   1932
# 5                She Done Him Wrong   1933
# 6             It Happened One Night   1934
# 7                           Top Hat   1935
# 8                      Modern Times   1936
# 9   The Charge of the Light Brigade   1936
# 10  Snow White and the Seven Dwarfs   1937
# 11            The Prisoner of Zenda   1937
# 12         Alexander's Ragtime Band   1938
# 13       You Can't Take It with You   1938
# 14               Gone with the Wind   1939
# 15     Mr. Smith Goes to Washington   1939
# 16                 The Wizard of Oz   1939
# 17                        Boom Town   1940
# 18                         Fantasia   1940
# 19                        Pinocchio   1940
# 20                          Rebecca   1940
# ...

# %%
df=pd.read_excel("c:/Users/Raju/Downloads/movies_sheets.xls",usecols="A,B,C")
df
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                           Category
# 0                Drama|History|War
# 1                      Crime|Drama
# 2                Drama|Romance|War
# 3                     Drama|Sci-Fi
# 4              Crime|Drama|Romance
# ...

# %%
df=pd.read_excel("c:/Users/Raju/Downloads/movies_sheets.xls",usecols="A:K")
df
# Out:
#                                                   Title  Year  \
# 0     Intolerance: Love's Struggle Throughout the Ages   1916
# 1                       Over the Hill to the Poorhouse   1920
# 2                                       The Big Parade   1925
# 3                                           Metropolis   1927
# 4                                        Pandora's Box   1929
# ...                                                 ...   ...
# 1333                                  Twin Falls Idaho   1999
# 1334                     Universal Soldier: The Return   1999
# 1335                                     Varsity Blues   1999
# 1336                                    Wild Wild West   1999
# 1337                                    Wing Commander   1999
#
#                           Category Language  Country Content Rating  Duration  \
# 0                Drama|History|War      NaN      USA      Not Rated       123
# ...

# %%
df=pd.read_excel("c:/Users/Raju/Downloads/movies_sheets.xls",usecols="A,D:K")
df
# Out:
#                                                   Title Language  Country  \
# 0     Intolerance: Love's Struggle Throughout the Ages       NaN      USA
# 1                       Over the Hill to the Poorhouse       NaN      USA
# 2                                       The Big Parade       NaN      USA
# 3                                           Metropolis    German  Germany
# 4                                        Pandora's Box    German  Germany
# ...                                                 ...      ...      ...
# 1333                                  Twin Falls Idaho   English      USA
# 1334                     Universal Soldier: The Return   English      USA
# 1335                                     Varsity Blues   English      USA
# 1336                                    Wild Wild West   English      USA
# 1337                                    Wing Commander   English      USA
#
#      Content Rating  Duration  Aspect Ratio       Budget  Gross Earnings  \
# ...

# %%
df=pd.read_csv("c:/Users/Raju/Downloads/clothes.txt")
df
# Out:
#     small  10       cob
# 0  medium  12     peter
# 1   large  15     monte
# 2   Small  11     monte
# 3  medium  10  cantabil
# 4  Medium  10       cob

# %%
df=pd.read_csv("c:/Users/Raju/Downloads/clothes.txt",header=None)
df
# Out:
#         0   1         2
# 0   small  10       cob
# 1  medium  12     peter
# 2   large  15     monte
# 3   Small  11     monte
# 4  medium  10  cantabil
# 5  Medium  10       cob

# %%
df=pd.read_csv("c:/Users/Raju/Downloads/clothes.txt",header=None,names=['A','B','Z'])
df
# Out:
#         A   B         Z
# 0   small  10       cob
# 1  medium  12     peter
# 2   large  15     monte
# 3   Small  11     monte
# 4  medium  10  cantabil
# 5  Medium  10       cob

# %%
df=pd.read_csv("c:/Users/Raju/Downloads/clothes1.txt")
df
# Out:
#      size:price:brand
# 0        small:10:cob
# 1     medium:12:peter
# 2      large:15:monte
# 3      small:11:monte
# 4  medium:10:cantabil
# 5       medium:10:cob

# %%
df=pd.read_csv("c:/Users/Raju/Downloads/clothes1.txt",delimiter=":")
df
# Out:
#      size  price     brand
# 0   small     10       cob
# 1  medium     12     peter
# 2   large     15     monte
# 3   small     11     monte
# 4  medium     10  cantabil
# 5  medium     10       cob

# %%
df=pd.read_csv("c:/Users/Raju/Downloads/clothes1.txt",sep=":")
df
# Out:
#      size  price     brand
# 0   small     10       cob
# 1  medium     12     peter
# 2   large     15     monte
# 3   small     11     monte
# 4  medium     10  cantabil
# 5  medium     10       cob

# %%
df=pd.read_csv("c:/Users/Raju/Downloads/clothes2.txt",sep="\t")
df
# Out:
#      size  price     brand
# 0   small     10       cob
# 1  medium     12     peter
# 2   large     15     monte
# 3   small     11     monte
# 4  medium     10  cantabil
# 5  medium     10     monte

# %%
df=pd.read_csv("c:/Users/Raju/Downloads/clothes3.csv")
df
# Out:
#      size     price  brand
# 0   small        10    cob
# 1  medium        12  peter
# 2   large        15  monte
# 3   small        11  monte
# 4  medium  cantabil    NaN
# 5  medium        10  monte

# %%
import pymysql
import sqlalchemy
conobj=sqlalchemy.create_engine("mysql+pymysql://root:root@localhost/1130to1")
df=pd.read_sql("select * from emp",conobj)
df
# Out:
#     empid      empname   empsal      dept
# 0     101        zampa  25000.0   bowling
# 1     102         monu  34505.1  operator
# 2     103        ishan  25188.1    coding
# 3     104        surya  27850.1    coding
# 4     105        bhola  43822.1   account
# 5     106      maxwell  30000.0   batting
# 6     108        smith  30000.0   batting
# 7     109         pant  50000.0   batting
# 8     110        radha  20000.0  cleaning
# 9     111        shyam  30000.0        hr
# 10    211  virat kohli  67780.1   account
# 11    224       bumhra  46484.1    coding
# 12    226       hardik  21195.1  operator
# 13    228        rahul  35836.1    coding
# 14    600        cahal  54470.1   account
# 15    601       chintu  19864.1    coding

# %%
conobj=sqlalchemy.create_engine("mysql+pymysql://root:root@localhost/1130to1")
df=pd.read_sql("select empid,empsal from emp",conobj)
df
# Out:
#     empid   empsal
# 0     601  19864.1
# 1     110  20000.0
# 2     226  21195.1
# 3     101  25000.0
# 4     103  25188.1
# 5     104  27850.1
# 6     106  30000.0
# 7     108  30000.0
# 8     111  30000.0
# 9     102  34505.1
# 10    228  35836.1
# 11    105  43822.1
# 12    224  46484.1
# 13    109  50000.0
# 14    600  54470.1
# 15    211  67780.1

# %%
conobj=sqlalchemy.create_engine("mysql+pymysql://root:root@localhost/1130to1")
df=pd.read_sql("select * from emp where empsal>20000",conobj)
df
# Out:
#     empid      empname   empsal      dept
# 0     101        zampa  25000.0   bowling
# 1     102         monu  34505.1  operator
# 2     103        ishan  25188.1    coding
# 3     104        surya  27850.1    coding
# 4     105        bhola  43822.1   account
# 5     106      maxwell  30000.0   batting
# 6     108        smith  30000.0   batting
# 7     109         pant  50000.0   batting
# 8     111        shyam  30000.0        hr
# 9     211  virat kohli  67780.1   account
# 10    224       bumhra  46484.1    coding
# 11    226       hardik  21195.1  operator
# 12    228        rahul  35836.1    coding
# 13    600        cahal  54470.1   account

# %%
df=pd.read_json("c:/Users/Raju/Downloads/students.json")
df
# Out:
#      name  age  roll
# 0    sonu   20   101
# 1    monu   21   102
# 2  chintu   10   103
# 3   pintu   25   104

# %%
df_list=pd.read_html("c:/Users/Raju/Downloads/test.html")
df1=df_list[0]
df1
# Out:
#    Name  Roll
# 0  Sonu  1001
# 1  Monu  1002

# %%
df2=df_list[1]
df2
# Out:
#     Name  Salary
# 0   Ajay   10000
# 1  Vijay   20000

# %%
import pandas as pd

# %%
df=pd.read_csv("c:/Users/Raju/Downloads/restaurant.csv")
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.total_bill
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
bill=df.total_bill
print(type(bill))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df['gender']
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: gender, Length: 244, dtype: object

# %%
df.gender
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: gender, Length: 244, dtype: object

# %%
df.total_bill
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.size
# Out:
# 1708

# %%
df['size']
# Out:
# 0      2
# 1      3
# 2      3
# 3      2
# 4      4
#       ..
# 239    3
# 240    2
# 241    2
# 242    2
# 243    2
# Name: size, Length: 244, dtype: int64

# %%
x='gender'
# df.x error
df[x]
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: gender, Length: 244, dtype: object

# %%
df['gender']
# Out:
# 0      Female
# 1        Male
# 2        Male
# 3        Male
# 4      Female
#         ...
# 239      Male
# 240    Female
# 241      Male
# 242      Male
# 243    Female
# Name: gender, Length: 244, dtype: object

# %%
df[['gender']]
# Out:
#      gender
# 0    Female
# 1      Male
# 2      Male
# 3      Male
# 4    Female
# ..      ...
# 239    Male
# 240  Female
# 241    Male
# 242    Male
# 243  Female
#
# [244 rows x 1 columns]

# %%
df[['gender','total_bill']]
# Out:
#      gender  total_bill
# 0    Female       16.99
# 1      Male       10.34
# 2      Male       21.01
# 3      Male       23.68
# 4    Female       24.59
# ..      ...         ...
# 239    Male       29.03
# 240  Female       27.18
# 241    Male       22.67
# 242    Male       17.82
# 243  Female       18.78
#
# [244 rows x 2 columns]

# %%
s=pd.Series([1,2,3,4,5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s=pd.Series([1,2,3,4,5],name='roll')
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: roll, dtype: int64

# %%
s=pd.Series([1,2,3,4,5],name='marks')
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: marks, dtype: int64

# %%
s=pd.Series([80,67,45,90,51],name='marks',index=['english','math','science','computer','hindi'])
s
# Out:
# english     80
# math        67
# science     45
# computer    90
# hindi       51
# Name: marks, dtype: int64

# %%
s.sum()
# Out:
# 333

# %%
s.mean()
# Out:
# 66.6

# %%
s[s>=60]
# Out:
# english     80
# math        67
# computer    90
# Name: marks, dtype: int64

# %%
s+2
# Out:
# english     82
# math        69
# science     47
# computer    92
# hindi       53
# Name: marks, dtype: int64

# %%
s.loc['math']
# Out:
# 67

# %%
s
# Out:
# english     80
# math        67
# science     45
# computer    90
# hindi       51
# Name: marks, dtype: int64

# %%
s.iloc[1]
# Out:
# 67

# %%
s.iloc[1]=70

# %%
s
# Out:
# english     80
# math        70
# science     45
# computer    90
# hindi       51
# Name: marks, dtype: int64

# %%
s.loc['math']=75
s
# Out:
# english     80
# math        75
# science     45
# computer    90
# hindi       51
# Name: marks, dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.shape
# Out:
# (5,)

# %%
s.index
# Out:
# Index(['english', 'math', 'science', 'computer', 'hindi'], dtype='object')

# %%
s.values
# Out:
# array([80, 75, 45, 90, 51], dtype=int64)

# %%
s.loc['math']
# Out:
# 75

# %%
s.math
# Out:
# 75

# %%
s.index=[10,20,30,40,50]
s
# Out:
# 10    80
# 20    75
# 30    45
# 40    90
# 50    51
# Name: marks, dtype: int64

# %%
s.index=[10,'twenty',30,40,50]
s
# Out:
# 10        80
# twenty    75
# 30        45
# 40        90
# 50        51
# Name: marks, dtype: int64

# %%
s.loc['twenty']
# Out:
# 75

# %%
s.loc[10]
# Out:
# 80

# %%
s.iloc[1]
# Out:
# 75

# %%
s.iloc[0]
# Out:
# 80

# %%
s.index=range(5)
s
# Out:
# 0    80
# 1    75
# 2    45
# 3    90
# 4    51
# Name: marks, dtype: int64

# %%
ss=s.drop(3)
ss
# Out:
# 0    80
# 1    75
# 2    45
# 4    51
# Name: marks, dtype: int64

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.total_bill.sum()
# Out:
# 4827.77

# %%
df.total_bill.mean()
# Out:
# 19.78594262295082

# %%
df.total_bill.max()
# Out:
# 50.81

# %%
df.total_bill.min()
# Out:
# 3.07

# %%
df.total_bill.median()
# Out:
# 17.795

# %%
df.total_bill.std()
# Out:
# 8.902411954856856

# %%
df.gender.sum()
# Out:
# '...'

# %%
# df.gender.mean() error
df.gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df.day.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df.gender.value_counts()
# Out:
# gender
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
df.day.value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
import pandas as pd

# %%
df=pd.read_csv("c:/Users/Raju/Downloads/restaurant.csv")
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.select_dtypes(include="int")
# Out:
#      size
# 0       2
# 1       3
# 2       3
# 3       2
# 4       4
# ..    ...
# 239     3
# 240     2
# 241     2
# 242     2
# 243     2
#
# [244 rows x 1 columns]

# %%
df.select_dtypes(include="float")
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
df.select_dtypes(include=['int','float'])
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
df.select_dtypes(include='object')
# Out:
#      gender smoker   day    time
# 0    Female     No   Sun  Dinner
# 1      Male     No   Sun  Dinner
# 2      Male     No   Sun  Dinner
# 3      Male     No   Sun  Dinner
# 4    Female     No   Sun  Dinner
# ..      ...    ...   ...     ...
# 239    Male     No   Sat  Dinner
# 240  Female    Yes   Sat  Dinner
# 241    Male    Yes   Sat  Dinner
# 242    Male     No   Sat  Dinner
# 243  Female     No  Thur  Dinner
#
# [244 rows x 4 columns]

# %%
df.select_dtypes(exclude='object')
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
df.total_bill.mean()
# Out:
# 19.78594262295082

# %%
df.tip.mean()
# Out:
# 2.99827868852459

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.shape
# Out:
# (244, 7)

# %%
df.describe(include='object')
# Out:
#        gender smoker  day    time
# count     244    244  244     244
# unique      2      2    4       2
# top      Male     No  Sat  Dinner
# freq      157    151   87     176

# %%
df.describe(include='all')
# Out:
#         total_bill         tip gender smoker  day    time        size
# count   244.000000  244.000000    244    244  244     244  244.000000
# unique         NaN         NaN      2      2    4       2         NaN
# top            NaN         NaN   Male     No  Sat  Dinner         NaN
# freq           NaN         NaN    157    151   87     176         NaN
# mean     19.785943    2.998279    NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638    NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000    NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000    NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000    NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500    NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000    NaN    NaN  NaN     NaN    6.000000

# %%
df_result=df.describe(include='all')

# %%
df_result
# Out:
#         total_bill         tip gender smoker  day    time        size
# count   244.000000  244.000000    244    244  244     244  244.000000
# unique         NaN         NaN      2      2    4       2         NaN
# top            NaN         NaN   Male     No  Sat  Dinner         NaN
# freq           NaN         NaN    157    151   87     176         NaN
# mean     19.785943    2.998279    NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638    NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000    NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000    NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000    NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500    NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000    NaN    NaN  NaN     NaN    6.000000

# %%
df.to_excel("d:/rest.xlsx",sheet_name='input_data')

# %%
df_result.to_excel("d:/rest.xlsx",sheet_name="output_data",index=False)

# %%
df.to_excel("d:/rest.xlsx",sheet_name="input_data",index=False)

# %%
ew=pd.ExcelWriter("d:/rest.xlsx",mode="a")
df_result.to_excel(ew,sheet_name='output_data')
ew.close()

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.sort_values(by="total_bill")
# Out:
#      total_bill    tip  gender smoker   day    time  size
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 149        7.51   2.00    Male     No  Thur   Lunch     2
# ..          ...    ...     ...    ...   ...     ...   ...
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
#
# [244 rows x 7 columns]

# %%
df.sort_values(by="total_bill",ascending=False)
# Out:
#      total_bill    tip  gender smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# ..          ...    ...     ...    ...   ...     ...   ...
# 149        7.51   2.00    Male     No  Thur   Lunch     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
#
# [244 rows x 7 columns]

# %%
df.sort_values(by=['total_bill','size'],ascending=False)
# Out:
#      total_bill    tip  gender smoker   day    time  size
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# ..          ...    ...     ...    ...   ...     ...   ...
# 149        7.51   2.00    Male     No  Thur   Lunch     2
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 111        7.25   1.00  Female     No   Sat  Dinner     1
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1
#
# [244 rows x 7 columns]

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head(10)
# Out:
#    total_bill   tip  gender smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
df.head()
# Out:
#    total_bill   tip  gender smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.head(300)
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.head(-5)
# Out:
#      total_bill   tip  gender smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 234       15.53  3.00    Male    Yes  Sat  Dinner     2
# 235       10.07  1.25    Male     No  Sat  Dinner     2
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2
# 238       35.83  4.67  Female     No  Sat  Dinner     3
#
# [239 rows x 7 columns]

# %%
df.tail()
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
df.tail(-5)
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 5         25.29  4.71    Male     No   Sun  Dinner     4
# 6          8.77  2.00    Male     No   Sun  Dinner     2
# 7         26.88  3.12    Male     No   Sun  Dinner     4
# 8         15.04  1.96    Male     No   Sun  Dinner     2
# 9         14.78  3.23    Male     No   Sun  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [239 rows x 7 columns]

# %%
df.sample(n=10)
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 79        17.29  2.71    Male     No  Thur   Lunch     2
# 153       24.55  2.00    Male     No   Sun  Dinner     4
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# 141       34.30  6.70    Male     No  Thur   Lunch     6
# 102       44.30  2.50  Female    Yes   Sat  Dinner     3
# 176       17.89  2.00    Male    Yes   Sun  Dinner     2
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 45        18.29  3.00    Male     No   Sun  Dinner     2
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2
# 162       16.21  2.00  Female     No   Sun  Dinner     3

# %%
df.sample(frac=.1)
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 25        17.81  2.34    Male     No   Sat  Dinner     4
# 80        19.44  3.00    Male    Yes  Thur   Lunch     2
# 140       17.47  3.50  Female     No  Thur   Lunch     2
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 16        10.33  1.67  Female     No   Sun  Dinner     3
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 120       11.69  2.31    Male     No  Thur   Lunch     2
# 184       40.55  3.00    Male    Yes   Sun  Dinner     2
# 43         9.68  1.32    Male     No   Sun  Dinner     2
# 98        21.01  3.00    Male    Yes   Fri  Dinner     2
# 150       14.07  2.50    Male     No   Sun  Dinner     2
# 94        22.75  3.25  Female     No   Fri  Dinner     2
# 175       32.90  3.11    Male    Yes   Sun  Dinner     2
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4
# 126        8.52  1.48    Male     No  Thur   Lunch     2
# ...

# %%
# df.sample(frac=.1,n=10) error

# %%
# df.sample(n=250) error

# %%
df.sample(n=300,replace=True)
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 49        18.04  3.00    Male     No   Sun  Dinner     2
# 121       13.42  1.68  Female     No  Thur   Lunch     2
# 96        27.28  4.00    Male    Yes   Fri  Dinner     2
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 69        15.01  2.09    Male    Yes   Sat  Dinner     2
# ..          ...   ...     ...    ...   ...     ...   ...
# 146       18.64  1.36  Female     No  Thur   Lunch     3
# 136       10.33  2.00  Female     No  Thur   Lunch     2
# 82        10.07  1.83  Female     No  Thur   Lunch     1
# 113       23.95  2.55    Male     No   Sun  Dinner     2
# 59        48.27  6.73    Male     No   Sat  Dinner     4
#
# [300 rows x 7 columns]

# %%
df.sample(n=10,replace=True)
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 123       15.95  2.00    Male     No  Thur   Lunch     2
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 12        15.42  1.57    Male     No   Sun  Dinner     2
# 171       15.81  3.16    Male    Yes   Sat  Dinner     2
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 138       16.00  2.00    Male    Yes  Thur   Lunch     2
# 188       18.15  3.50  Female    Yes   Sun  Dinner     3
# 28        21.70  4.30    Male     No   Sat  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ##### Conditional slicing

# %%
df[df.time=='Dinner']
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [176 rows x 7 columns]

# %%
df[df.time=='Dinner'].total_bill.mean()
# Out:
# 20.79715909090909

# %%
df.total_bill.mean()
# Out:
# 19.78594262295082

# %%
df[df.time=='Lunch'].total_bill.mean()
# Out:
# 17.168676470588235

# %%
df[df.gender=='Male'].shape
# Out:
# (157, 7)

# %%
df[df.gender=='Female'].shape
# Out:
# (87, 7)

# %%
df[(df.gender=='Female') & (df.time=='Dinner')].shape
# Out:
# (52, 7)

# %%
df[(df.gender=='Female') & (df.time=='Lunch')].shape
# Out:
# (35, 7)

# %%
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.groupby(by="day").total_bill.agg(['count','mean'])
# Out:
#       count       mean
# day
# Fri      19  17.151579
# Sat      87  20.441379
# Sun      76  21.410000
# Thur     62  17.682742

# %%
df.groupby(by=["day","time"]).total_bill.agg(['count','mean'])
# Out:
#              count       mean
# day  time
# Fri  Dinner     12  19.663333
#      Lunch       7  12.845714
# Sat  Dinner     87  20.441379
# Sun  Dinner     76  21.410000
# Thur Dinner      1  18.780000
#      Lunch      61  17.664754

# %%
df.groupby(by=['day','time','gender']).total_bill.agg(['count','mean'])
# Out:
#                     count       mean
# day  time   gender
# Fri  Dinner Female      5  14.310000
#             Male        7  23.487143
#      Lunch  Female      4  13.940000
#             Male        3  11.386667
# Sat  Dinner Female     28  19.680357
#             Male       59  20.802542
# Sun  Dinner Female     18  19.872222
#             Male       58  21.887241
# Thur Dinner Female      1  18.780000
#      Lunch  Female     31  16.648710
#             Male       30  18.714667

# %%
df.groupby(by=['day','time','gender'])[['total_bill','tip']].agg(['count','mean'])
# Out:
#                    total_bill              tip
#                         count       mean count      mean
# day  time   gender
# Fri  Dinner Female          5  14.310000     5  2.810000
#             Male            7  23.487143     7  3.032857
#      Lunch  Female          4  13.940000     4  2.745000
#             Male            3  11.386667     3  1.900000
# Sat  Dinner Female         28  19.680357    28  2.801786
#             Male           59  20.802542    59  3.083898
# Sun  Dinner Female         18  19.872222    18  3.367222
#             Male           58  21.887241    58  3.220345
# Thur Dinner Female          1  18.780000     1  3.000000
#      Lunch  Female         31  16.648710    31  2.561935
#             Male           30  18.714667    30  2.980333

# %%
report=df.groupby(by=["day","time","gender"])[['total_bill','tip']].agg(['count','mean'])
ew=pd.ExcelWriter("d:/rest.xlsx",mode="a")
report.to_excel(ew,sheet_name='final_report')
ew.close()

# %%
df.groupby(by='day').total_bill.agg(['count','mean'])
# Out:
#       count       mean
# day
# Fri      19  17.151579
# Sat      87  20.441379
# Sun      76  21.410000
# Thur     62  17.682742

# %%
df.pivot_table(index="day",values='total_bill',aggfunc=['count','mean'])
# Out:
#           count       mean
#      total_bill total_bill
# day
# Fri          19  17.151579
# Sat          87  20.441379
# Sun          76  21.410000
# Thur         62  17.682742

# %%
df.pivot_table(index=["day","time"],values='total_bill',aggfunc=['count','mean'])
# Out:
#                  count       mean
#             total_bill total_bill
# day  time
# Fri  Dinner         12  19.663333
#      Lunch           7  12.845714
# Sat  Dinner         87  20.441379
# Sun  Dinner         76  21.410000
# Thur Dinner          1  18.780000
#      Lunch          61  17.664754

# %%
df=pd.read_csv("c:/Users/Raju/Downloads/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Pclass.value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
87/184
# Out:
# 0.47282608695652173

# %% [markdown]
# kaggle.com

# %%
df=pd.read_csv("c:/Users/Raju/Downloads/restaurant.csv")
df
# Out:
#      total_bill   tip  gender smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.groupby(by="day").total_bill.agg(['count','mean'])
# Out:
#       count       mean
# day
# Fri      19  17.151579
# Sat      87  20.441379
# Sun      76  21.410000
# Thur     62  17.682742

# %%
df.pivot_table(index='day',values='total_bill',aggfunc=['count','mean'])
# Out:
#           count       mean
#      total_bill total_bill
# day
# Fri          19  17.151579
# Sat          87  20.441379
# Sun          76  21.410000
# Thur         62  17.682742

# %%
df.groupby(by=['day','time']).total_bill.agg(['count','mean'])
# Out:
#              count       mean
# day  time
# Fri  Dinner     12  19.663333
#      Lunch       7  12.845714
# Sat  Dinner     87  20.441379
# Sun  Dinner     76  21.410000
# Thur Dinner      1  18.780000
#      Lunch      61  17.664754

# %%
df.pivot_table(index=["day","time"],values="total_bill",aggfunc=['count','mean'])
# Out:
#                  count       mean
#             total_bill total_bill
# day  time
# Fri  Dinner         12  19.663333
#      Lunch           7  12.845714
# Sat  Dinner         87  20.441379
# Sun  Dinner         76  21.410000
# Thur Dinner          1  18.780000
#      Lunch          61  17.664754

# %%
df.groupby(by=['day','time','gender']).total_bill.agg(['count','mean'])
# Out:
#                     count       mean
# day  time   gender
# Fri  Dinner Female      5  14.310000
#             Male        7  23.487143
#      Lunch  Female      4  13.940000
#             Male        3  11.386667
# Sat  Dinner Female     28  19.680357
#             Male       59  20.802542
# Sun  Dinner Female     18  19.872222
#             Male       58  21.887241
# Thur Dinner Female      1  18.780000
#      Lunch  Female     31  16.648710
#             Male       30  18.714667

# %%
df.pivot_table(index='day',columns='time',values='total_bill',aggfunc=['count','mean'])
# Out:
#       count             mean
# time Dinner Lunch     Dinner      Lunch
# day
# Fri    12.0   7.0  19.663333  12.845714
# Sat    87.0   NaN  20.441379        NaN
# Sun    76.0   NaN  21.410000        NaN
# Thur    1.0  61.0  18.780000  17.664754

# %%
df.pivot_table(index=['day','time'],columns='gender',values='total_bill',aggfunc=['count','mean'])
# Out:
#              count             mean
# gender      Female  Male     Female       Male
# day  time
# Fri  Dinner    5.0   7.0  14.310000  23.487143
#      Lunch     4.0   3.0  13.940000  11.386667
# Sat  Dinner   28.0  59.0  19.680357  20.802542
# Sun  Dinner   18.0  58.0  19.872222  21.887241
# Thur Dinner    1.0   NaN  18.780000        NaN
#      Lunch    31.0  30.0  16.648710  18.714667

# %%
df.pivot_table(index=['day','time','gender'],values='total_bill',aggfunc=['count','mean'])
# Out:
#                         count       mean
#                    total_bill total_bill
# day  time   gender
# Fri  Dinner Female          5  14.310000
#             Male            7  23.487143
#      Lunch  Female          4  13.940000
#             Male            3  11.386667
# Sat  Dinner Female         28  19.680357
#             Male           59  20.802542
# Sun  Dinner Female         18  19.872222
#             Male           58  21.887241
# Thur Dinner Female          1  18.780000
#      Lunch  Female         31  16.648710
#             Male           30  18.714667

# %%
df.pivot_table(index='day',columns=['time','gender'],values="total_bill",aggfunc=["count",'mean'])
# Out:
#         count                          mean
# time   Dinner        Lunch           Dinner                Lunch
# gender Female  Male Female  Male     Female       Male    Female       Male
# day
# Fri       5.0   7.0    4.0   3.0  14.310000  23.487143  13.94000  11.386667
# Sat      28.0  59.0    NaN   NaN  19.680357  20.802542       NaN        NaN
# Sun      18.0  58.0    NaN   NaN  19.872222  21.887241       NaN        NaN
# Thur      1.0   NaN   31.0  30.0  18.780000        NaN  16.64871  18.714667

# %%
df.pivot_table(index='day',columns=['time','gender'],values=['total_bill','tip'],aggfunc=['count','mean'])
# Out:
#         count                                                       mean  \
#           tip                    total_bill                          tip
# time   Dinner        Lunch           Dinner        Lunch          Dinner
# gender Female  Male Female  Male     Female  Male Female  Male    Female
# day
# Fri       5.0   7.0    4.0   3.0        5.0   7.0    4.0   3.0  2.810000
# Sat      28.0  59.0    NaN   NaN       28.0  59.0    NaN   NaN  2.801786
# Sun      18.0  58.0    NaN   NaN       18.0  58.0    NaN   NaN  3.367222
# Thur      1.0   NaN   31.0  30.0        1.0   NaN   31.0  30.0  3.000000
#
#                                                                       \
#                                      total_bill
# time                 Lunch               Dinner                Lunch
# gender      Male    Female      Male     Female       Male    Female
# day
# Fri     3.032857  2.745000  1.900000  14.310000  23.487143  13.94000
# ...

# %%
df=pd.read_csv("c:/Users/Raju/Downloads/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df.gender.value_counts()
# Out:
# gender
# male      577
# female    314
# Name: count, dtype: int64

# %%
df[(df.gender=='male') & (df.Survived==1)]
# Out:
#      PassengerId  Survived  Pclass                             Name gender  \
# 17            18         1       2     Williams, Mr. Charles Eugene   male
# 21            22         1       2            Beesley, Mr. Lawrence   male
# 23            24         1       1     Sloper, Mr. William Thompson   male
# 36            37         1       3                 Mamee, Mr. Hanna   male
# 55            56         1       1                Woolner, Mr. Hugh   male
# ..           ...       ...     ...                              ...    ...
# 838          839         1       3                  Chip, Mr. Chang   male
# 839          840         1       1             Marechal, Mr. Pierre   male
# 857          858         1       1           Daly, Mr. Peter Denis    male
# 869          870         1       3  Johnson, Master. Harold Theodor   male
# 889          890         1       1            Behr, Mr. Karl Howell   male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
df[(df.gender=='male') & (df.Survived==1)].shape
# Out:
# (109, 12)

# %%
df[(df.gender=='female') & (df.Survived==1)].shape
# Out:
# (233, 12)

# %%
df.Pclass.value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
df[(df.Pclass==1) & (df.Survived==1)].shape
# Out:
# (136, 12)

# %%
df[(df.Pclass==2) & (df.Survived==1)].shape
# Out:
# (87, 12)

# %%
df[(df.Pclass==3) & (df.Survived==1)].shape
# Out:
# (119, 12)

# %%
df[df.Age>=70].shape
# Out:
# (7, 12)

# %%
df[df.Age>=60].shape
# Out:
# (26, 12)

# %%
df[(df.Age>=60) & (df.Survived==1)].shape
# Out:
# (7, 12)

# %%
df[(df.Age>=60) & (df.Survived==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 275          276         1       1
# 366          367         1       1
# 483          484         1       3
# 570          571         1       2
# 587          588         1       1
# 630          631         1       1
# 829          830         1       1
#
#                                                  Name  gender   Age  SibSp  \
# 275                 Andrews, Miss. Kornelia Theodosia  female  63.0      1
# 366  Warren, Mrs. Frank Manley (Anna Sophia Atkinson)  female  60.0      1
# 483                            Turkula, Mrs. (Hedwig)  female  63.0      0
# 570                                Harris, Mr. George    male  62.0      0
# 587                  Frolicher-Stehli, Mr. Maxmillian    male  60.0      1
# 630              Barkworth, Mr. Algernon Henry Wilson    male  80.0      0
# 829         Stone, Mrs. George Nelson (Martha Evelyn)  female  62.0      0
#
#      Parch       Ticket     Fare Cabin Embarked
# ...

# %%
df[(df.Parch==0) & (df.SibSp==0) & (df.Survived==1)].shape
# Out:
# (163, 12)

# %%
df.Age.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# gender           0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ##### data cleaning
# - handling missing values
# - handling data errors
# - handling incorrect values
# - handling duplicacy

# %%
import pandas as pd

# %%
df=pd.read_csv("c:/Users/Raju/Downloads/weather_data.txt")
df
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 1   1/4/2017          NaN        9.0   Sunny
# 2   1/5/2017         28.0        NaN    Snow
# 3   1/6/2017          NaN        7.0     NaN
# 4   1/7/2017         32.0        NaN    Rain
# 5   1/8/2017          NaN        NaN   Sunny
# 6   1/9/2017          NaN        NaN     NaN
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny

# %%
df.temperature.isnull().sum()
# Out:
# 4

# %%
df.isnull().sum()
# Out:
# day            0
# temperature    4
# windspeed      4
# event          2
# dtype: int64

# %%
df.dropna(subset=['temperature','windspeed'])
# Out:
#          day  temperature  windspeed   event
# 0   1/1/2017         32.0        6.0    Rain
# 7  1/10/2017         34.0        8.0  Cloudy
# 8  1/11/2017         40.0       12.0   Sunny
# 9  1/12/2017         30.0       10.0   Sunny
