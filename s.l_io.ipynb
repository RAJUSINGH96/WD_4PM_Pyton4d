# %%
import io
file=io.open(r"C:\Users\Raju\Documents\msg.txt","r")
text=file.read()
print(text)
file.close()
# Out:
# python is a funny language
# first released in 1991 by Guido van rossum
# bye

# %%
file=open(r"C:\Users\Raju\Documents\msg.txt","r")
text=file.read()
print(text)
file.close()
# Out:
# python is a funny language
# first released in 1991 by Guido van rossum
# bye

# %%
file=open(r"C:\Users\Raju\Documents\msg.txt","r")
text=file.read(3)
print(text)
text=file.read(5)
print(text)
text=file.read(-1)
print(text)
text=file.read(4)
print(text)
file.close()
# Out:
# pyt
# hon i
# s a funny language
# first released in 1991 by Guido van rossum
# bye

# %%
file=open(r"C:\Users\Raju\Documents\msg.txt","r")
file.seek(10)
text=file.read()
print(text)
file.close()
# Out:
# a funny language
# first released in 1991 by Guido van rossum
# bye

# %%
file=open(r"C:\Users\Raju\Documents\msg.txt","r")
text=file.read()
print(text)
file.seek(0)
text=file.read()
print(text)
file.close()
# Out:
# python is a funny language
# first released in 1991 by Guido van rossum
# bye
# python is a funny language
# first released in 1991 by Guido van rossum
# bye

# %%
file=open(r"C:\Users\Raju\Documents\msg.india","r")
text=file.read()
print(text)
file.close()
# Out:
# python is a funny language
# first released in 1991 by Guido van rossum
# bye take care.

# %%
file=open(r"C:\Users\Raju\Documents\msg.txt","r")
text=file.readline()
print(text)
text=file.read(3)
print(text)
text=file.readline()
print(text)
file.close()
# Out:
# python is a funny language
#
# fir
# st released in 1991 by Guido van rossum

# %%
file=open(r"C:\Users\Raju\Documents\msg.txt","r")
list_lines=file.readlines()
print(list_lines)
file.close()
# Out:
# ['python is a funny language\n', 'first released in 1991 by Guido van rossum\n', 'bye']

# %%
file=open(r"C:\Users\Raju\Documents\msg.txt","r")
for line in file:
    print(line,end="")
file.close()
# Out:
# python is a funny language
# first released in 1991 by Guido van rossum
# bye

# %%
file=open(r"C:\Users\Raju\Documents\msg.txt","r")
for line in file:
    print(line)
file.close()
# Out:
# python is a funny language
#
# first released in 1991 by Guido van rossum
#
# bye

# %%
file=open(r"C:\Users\Raju\Documents\hi.txt","r",encoding="utf")
text=file.read()
print(text)
file.close()
# Out:
# राम एक अच्छा लड़का है

# %%
file=open(r"C:\Users\Raju\Documents\msg.txt","r")
text=file.read()
print(text.upper())
file.close()
# Out:
# PYTHON IS A FUNNY LANGUAGE
# FIRST RELEASED IN 1991 BY GUIDO VAN ROSSUM
# BYE

# %%
file=open(r"C:\Users\Raju\Documents\msg.txt","r")
text=file.read()
print("fun" in text)
print(text.split())
print(text)
print(len(text))
# Out:
# True
# ['python', 'is', 'a', 'funny', 'language', 'first', 'released', 'in', '1991', 'by', 'Guido', 'van', 'rossum', 'bye']
# python is a funny language
# first released in 1991 by Guido van rossum
# bye
# 73

# %%
print(text[::-1])
# Out:
# eyb
# mussor nav odiuG yb 1991 ni desaeler tsrif
# egaugnal ynnuf a si nohtyp

# %%
file=open(r"d:\abc.txt","w")# write method say if file not present then it will create. but path must be present
file.write(str(2023))
file.write("python")
file.flush()
file.write("apple")
file.write("mango")
# Out:
# 5

# %%
file.flush()

# %%
print("hi")
print("bye")
# Out:
# hi
# bye

# %%
print("hi",end="\t")
print("bye")
# Out:
# hi	bye

# %%
file=open(r"d:\abc.txt","w")
file.write("india\n")
file.write("bharat\n")
file.close()

# %%
file=open(r"d:\abc.txt","a") # a append the data
file.write("python\n")
file.close()

# %%
# file=open(r"d:\abc.txt","x") # x mode always run on new file
# file.write("python\n")
# file.close()# error

# %%
file=open(r"d:\bcd.txt","x") 
file.write("python\n")
file.close()

# %%
file=open(r"d:\abcd.txt","w",encoding="utf") 
file.write("राम एक अच्छा लड़का है")
file.close()

# %%
# file=open(r"d:\abcd.txt","w",encoding="utf") 
# file.read()
# file.close()# error

# %%
#  mode                   if file does not exist                if file already exists
#     w                       create                              overwrite/replace
#     a                       create                              append
#     x                       create                              error

# %%
file=open(r"d:\abc.txt","r+")  # read then write
text=file.read()
print(text)
file.write("bye")
file.close()
# Out:
# india
# bharat
# python

# %%
# file=open(r"d:\ab.txt","r+")  # r+ does not create a file 
# file.write("hello")   # to run r+ file, file must be exists.
# file.close() # error

# %%
file=open(r"d:/aa.txt","w+")  # write and read.
file.write("python is a funny language")
# file.flush()
file.seek(0)
text=file.read() #if file is empty read method first read file in buffer then goes to file.
print(text)   # if file is full then first read the file then read the buffer.
file.close()
# Out:
# python is a funny language

# %%
file=open(r"d:\aa.txt","a+")  # append
file.write("python is a funny language")
file.seek(0)
text=file.read()
print(text)
file.close()
# Out:
# python is a funny languagepython is a funny languagepython is a funny languagepython is a funny language

# %%
# r
# w
# a
# x
# r+
# w+
# a+
#
#

# %%
# file=open(r"C:\Users\Raju\Downloads\j45","r")
# text=file.read()
# print(text)
# file.close()  # error

# %%
# text_data------------>str type
# non text data-------->byte type

# %%
file=open(r"d:\abc.txt","rb")
bytes_data=file.read()
print(bytes_data,type(bytes_data))
file.close()
# Out:
# b'india\r\nbharat\r\npython\r\nbye' <class 'bytes'>

# %%
file=open(r"d:\abc.txt","r")
bytes_data=file.read()
print(bytes_data,type(bytes_data))
file.close()
# Out:
# india
# bharat
# python
# bye <class 'str'>

# %%
file=open(r"C:\Users\Raju\Downloads\j45.JPG","rb")
bytes_data=file.read()
print(bytes_data)
file.close()
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc2\x00\x11\x08\x03\x84\x04\xb0\x03\x01"=id\x14\x81LU@\xd5F\xa5JJ\xe5A\x91,\x81\x8cS\x86l\x17\'\x08\xcdRGH\xa7\x94\x9d\x1c\x16\xdc\x9a\xda\xd8\xd4\xb9Q\xb5L\x13\xadq\x94\xabU\x17\x16!y&\x14\xe9BP\xec\x84\xc6lYM8\xd0i\xb6\xd6@p)\xa8\xb8\x0eD\tAA@\x14\x164\xa0\xdc\xa8\x11!\xa5V2\xa0\xaa\xa0Y\x01\x8d\xafK\xd3\xd1\xa1
# ...

# %%
file=open(r"C:\Users\Raju\Downloads\j45.JPG","rb")
bytes_data=file.read()
# print(bytes_data)
file.close()
file1=open(r"d:/r.jpg","wb")
file1.write(bytes_data)
file1.close()

# %%
file=open(r"C:\Users\Raju\Downloads\j45.JPG","rb")
bytes_data=file.read()
s="india123"
file.close()
file1=open(r"d:/rr.jpg","wb")
file1.write(bytes_data)
file1.write(s.encode())
file1.close()

# %%
file=open(r"d:/rr.jpg","rb")
x=file.read()
print(x)
file.close()
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342\xff\xdb\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222\xff\xc2\x00\x11\x08\x03\x84\x04\xb0\x03\x01"=id\x14\x81LU@\xd5F\xa5JJ\xe5A\x91,\x81\x8cS\x86l\x17\'\x08\xcdRGH\xa7\x94\x9d\x1c\x16\xdc\x9a\xda\xd8\xd4\xb9Q\xb5L\x13\xadq\x94\xabU\x17\x16!y&\x14\xe9BP\xec\x84\xc6lYM8\xd0i\xb6\xd6@p)\xa8\xb8\x0eD\tAA@\x14\x164\xa0\xdc\xa8\x11!\xa5V2\xa0\xaa\xa0Y\x01\x8d\xafK\xd3\xd1\xa1
# ...

# %%
file=open(r"d:/rr.jpg","rb")
x=file.read()
print(x[-8:])
print(x[-8:].decode())
file.close()
# Out:
# b'india123'
# india123

# %%
# with block------>automatically close the file.
with open(r"d:/abc.txt","r") as file:
    text=file.read()
    print(text)
print("bye")
# Out:
# india
# bharat
# python
# bye
# bye

# %%
file=open(r"d:/abc.txt")# automatocally default mode is r
text=file.read()
print(text)
file.close()
# Out:
# india
# bharat
# python
# bye
