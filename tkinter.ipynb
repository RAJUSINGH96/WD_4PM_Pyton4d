# %%
import random
import pyautogui as pg
import time
x=('lalji bhai','mayank bhai')
time.sleep(8)
for i in range(500):
    a=random.choice(x)
    pg.write('sorry'sorryl
    sorryl
    sorrya
    sorryl
    sorrya
    sorryi
    sorryi
    sorryl
    sorryl
    sorrya
    sorryl
    sorry 
    sorryl
    sorryj
    sorrya
    sorryj
    sorryb
    sorryb
    sorryj
    sorryj
    sorrya
    sorryl
    sorry 
    sorryj
    sorryl
    sorryi
    sorry 
    sorryh
    sorryi
    sorryi
    sorryi
    sorrya
    sorrya
    sorryl
    sorryh
    sorry 
    sorrya
    sorry 
    sorrya
    sorryl
    sorryi
    sorryi
    sorrya
    sorryi
    sorrya
    sorryl
    sorryh
    sorryi
    sorry 
    sorryb
    sorryl
    sorrya
    sorry 
    sorrya
    sorrya
    sorrya
    sorryl
    sorryi
    sorryl
    sorrya
    sorryj
    sorryi
    sorrya
    sorrya
    sorryi
    sorrya
    sorry 
    sorry 
    sorryb
    sorryl
    sorryl
    sorryi
    sorryb
    sorryl
    sorry 
    sorrya
    sorryl
    sorrya
    sorrya
    sorryb
    sorryb
    sorrya
    sorry 
    sorryi
    sorry 
    sorry 
    sorryl
    sorryl
    sorryl
    sorrya
    sorryi
    sorryb
    sorryl
    sorryb
    sorrya
    sorryl
    sorryl
    sorryl
    sorry 
    sorry 
    sorryi
    sorry 
    sorrya
    sorryj
    sorry 
    sorryi
    sorryi
    sorry 
    sorrya
    sorryj
    sorryl
    sorryl
    sorryl
    sorryl
    sorryh
    sorryl
    sorryb
    sorry 
    sorryi
    sorrya
    sorryl
    sorrya
    sorrya
    sorryh
    sorryh
    sorryl
    sorryi
    sorryb
    sorryi
    sorry 
    sorryj
    sorrya
    sorrya
    sorryj
    sorrya
    sorryl
    sorryb
    sorryi
    sorryi
    sorryb
    sorryb
    sorrya
    sorryj
    sorryi
    sorryi
    sorryi
    sorryb
    sorrya
    sorryb
    sorrya
    sorryb
    sorry 
    sorryi
    sorryb
    sorryl
    sorryi
    sorryb
    sorryl
    sorryb
    sorryi
    sorrya
    sorrya
    sorryb
    sorrya
    sorryi
    sorry 
    sorryj
    sorryl
    sorrya
    sorryl
    sorryl
    sorryi
    sorrya
    sorryl
    sorryl
    sorrya
    sorrya
    sorryl
    sorryi
    sorryb
    sorryl
    sorryl
    sorryl
    +a)
    pg.press('enter')
# Out:
#   Cell In[4], line 8
#     pg.write('sorry'sorryl
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# #### User interface
#  - CUI(character user interface)
#  - GUI(Graphical user interface)
#     - desktop based
#       - tkinter
#       - wxpython
#       - pyqt
#       - kivy
#       - etc.
#     - web based
#       - html
#       - css
#       - js
#       - bootstrap
#       - react
#       - etc.
#     - mobile based
#       - react
#       - kivy

# %% [markdown]
# ### tkinter
#  - it is a **standard python library** to create desktop based GUI application.
#  - this library provides set of graphical components(a.k.a widgets)
#  - **each widget is represented by an object**

# %%
from tkinter import *

# %%
win=Tk()  # create a window
win.mainloop()# make the win visible

# %%
win=Tk()  
win.mainloop()

# %%
win=Tk()
win.geometry("600x400")
win.mainloop()

# %%
win=Tk()
win.geometry("600x400")
win.mainloop()
